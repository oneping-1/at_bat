# %%
import json
from get.statsapi_plus import get_game_dict

data = get_game_dict(716518)

with open('game.json', 'w') as file:
    file.write(json.dumps(data, indent=4))

# %%
import json
import statsapi

standings_data = statsapi.get('standings', {'leagueId':103})

with open('standings.json', 'w', encoding='utf-8') as file:
    file.write(json.dumps(standings_data, indent=4))

print(f"AL West Magic Number: {standings_data['records'][2]['teamRecords'][0]['magicNumber']}")
# Out:
# AL West Magic Number: 7

# %%
import json
from get.game import Game

game = Game.get_game_from_pk(716850)

print(json.dumps(game.liveData._liveData, indent=4))
# Out:
# {
#     "plays": {
#         "allPlays": [
#             {
#                 "result": {
#                     "type": "atBat",
#                     "event": "Flyout",
#                     "eventType": "field_out",
#                     "description": "Marcus Semien flies out to right fielder Max Kepler.",
#                     "rbi": 0,
#                     "awayScore": 0,
#                     "homeScore": 0,
#                     "isOut": true
#                 },
#                 "about": {
#                     "atBatIndex": 0,
#                     "halfInning": "top",
#                     "isTopInning": true,
#                     "inning": 1,
#                     "startTime": "2023-08-26T00:11:30.652Z",
#                     "endTime": "2023-08-26T00:11:55.544Z",
#                     "isComplete": true,
#                     "isScoringPlay": false,
#                     "hasReview": false,
#                     "hasOut": true,
#                     "captivatingIndex": 0
#                 },
#                 "count": {
#                     "balls": 0,
#                     "strikes": 1,
#                     "outs": 1
#                 },
#                 "matchup": {
#                     "batter": {
#                         "id": 543760,
#                         "fullName": "Marcus Semien",
#                         "link": "/api/v1/people/543760"
#                     },
#                     "batSide": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "pitcher": {
#                         "id": 543243,
#                         "fullName": "Sonny Gray",
#                         "link": "/api/v1/people/543243"
#                     },
#                     "pitchHand": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "batterHotColdZones": [],
#                     "pitcherHotColdZones": [],
#                     "splits": {
#                         "batter": "vs_RHP",
#                         "pitcher": "vs_RHB",
#                         "menOnBase": "Empty"
#                     }
#                 },
#                 "pitchIndex": [
#                     3,
#                     4
#                 ],
#                 "actionIndex": [
#                     0,
#                     1,
#                     2
#                 ],
#                 "runnerIndex": [
#                     0
#                 ],
#                 "runners": [
#                     {
#                         "movement": {
#                             "originBase": null,
#                             "start": null,
#                             "end": null,
#                             "outBase": "1B",
#                             "isOut": true,
#                             "outNumber": 1
#                         },
#                         "details": {
#                             "event": "Flyout",
#                             "eventType": "field_out",
#                             "movementReason": null,
#                             "runner": {
#                                 "id": 543760,
#                                 "fullName": "Marcus Semien",
#                                 "link": "/api/v1/people/543760"
#                             },
#                             "responsiblePitcher": null,
#                             "isScoringEvent": false,
#                             "rbi": false,
#                             "earned": false,
#                             "teamUnearned": false,
#                             "playIndex": 4
#                         },
#                         "credits": [
#                             {
#                                 "player": {
#                                     "id": 596146,
#                                     "link": "/api/v1/people/596146"
#                                 },
#                                 "position": {
#                                     "code": "9",
#                                     "name": "Outfielder",
#                                     "type": "Outfielder",
#                                     "abbreviation": "RF"
#                                 },
#                                 "credit": "f_putout"
#                             }
#                         ]
#                     }
#                 ],
#                 "playEvents": [
#                     {
#                         "details": {
#                             "description": "Status Change - Pre-Game",
#                             "event": "Game Advisory",
#                             "eventType": "game_advisory",
#                             "awayScore": 0,
#                             "homeScore": 0,
#                             "isScoringPlay": false,
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 0,
#                             "outs": 0
#                         },
#                         "index": 0,
#                         "startTime": "2023-08-25T22:01:55.966Z",
#                         "endTime": "2023-08-25T23:39:53.087Z",
#                         "isPitch": false,
#                         "type": "action",
#                         "player": {
#                             "id": 543760,
#                             "link": "/api/v1/people/543760"
#                         }
#                     },
#                     {
#                         "details": {
#                             "description": "Status Change - Warmup",
#                             "event": "Game Advisory",
#                             "eventType": "game_advisory",
#                             "awayScore": 0,
#                             "homeScore": 0,
#                             "isScoringPlay": false,
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 0,
#                             "outs": 0
#                         },
#                         "index": 1,
#                         "startTime": "2023-08-25T23:39:53.087Z",
#                         "endTime": "2023-08-26T00:09:46.628Z",
#                         "isPitch": false,
#                         "type": "action",
#                         "player": {
#                             "id": 543760,
#                             "link": "/api/v1/people/543760"
#                         }
#                     },
#                     {
#                         "details": {
#                             "description": "Status Change - In Progress",
#                             "event": "Game Advisory",
#                             "eventType": "game_advisory",
#                             "awayScore": 0,
#                             "homeScore": 0,
#                             "isScoringPlay": false,
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 0,
#                             "outs": 0
#                         },
#                         "index": 2,
#                         "startTime": "2023-08-26T00:09:46.628Z",
#                         "endTime": "2023-08-26T00:11:33.020Z",
#                         "isPitch": false,
#                         "type": "action",
#                         "player": {
#                             "id": 543760,
#                             "link": "/api/v1/people/543760"
#                         }
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "C",
#                                 "description": "Called Strike"
#                             },
#                             "description": "Called Strike",
#                             "code": "C",
#                             "ballColor": "rgba(170, 21, 11, 1.0)",
#                             "trailColor": "rgba(50, 0, 221, 1.0)",
#                             "isInPlay": false,
#                             "isStrike": true,
#                             "isBall": false,
#                             "type": {
#                                 "code": "SI",
#                                 "description": "Sinker"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 1,
#                             "outs": 0
#                         },
#                         "pitchData": {
#                             "startSpeed": 93.1,
#                             "endSpeed": 86.5,
#                             "strikeZoneTop": 3.31900150506662,
#                             "strikeZoneBottom": 1.59415974467542,
#                             "coordinates": {
#                                 "aY": 25.342317628750365,
#                                 "aZ": -23.359988984343822,
#                                 "pfxX": -7.240921821040321,
#                                 "pfxZ": 4.65685758645839,
#                                 "pX": 0.33178077123007765,
#                                 "pZ": 2.692532440317567,
#                                 "vX0": 5.5291570839046065,
#                                 "vY0": -135.66569376560213,
#                                 "vZ0": -3.3323835914087447,
#                                 "x": 104.35,
#                                 "y": 166.08,
#                                 "x0": -0.7762206096458367,
#                                 "y0": 50.00420396080183,
#                                 "z0": 5.536230694816708,
#                                 "aX": -13.709196229157575
#                             },
#                             "breaks": {
#                                 "breakAngle": 27.6,
#                                 "breakLength": 6.0,
#                                 "breakY": 24.0,
#                                 "breakVertical": -23.0,
#                                 "breakVerticalInduced": 8.0,
#                                 "breakHorizontal": 12.2,
#                                 "spinRate": 2490,
#                                 "spinDirection": 200
#                             },
#                             "zone": 6,
#                             "typeConfidence": 0.92,
#                             "plateTime": 0.4013505313786254,
#                             "extension": 6.377722779918365
#                         },
#                         "index": 3,
#                         "playId": "ab109a48-0524-455a-9eee-4f99cb8e02d1",
#                         "pitchNumber": 1,
#                         "startTime": "2023-08-26T00:11:33.020Z",
#                         "endTime": "2023-08-26T00:11:37.004Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "X",
#                                 "description": "In play, out(s)"
#                             },
#                             "description": "In play, out(s)",
#                             "code": "X",
#                             "ballColor": "rgba(26, 86, 190, 1.0)",
#                             "trailColor": "rgba(50, 50, 50, 1.0)",
#                             "isInPlay": true,
#                             "isStrike": false,
#                             "isBall": false,
#                             "type": {
#                                 "code": "ST",
#                                 "description": "Sweeper"
#                             },
#                             "isOut": true,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 1,
#                             "outs": 0
#                         },
#                         "pitchData": {
#                             "startSpeed": 84.6,
#                             "endSpeed": 78.3,
#                             "strikeZoneTop": 3.32,
#                             "strikeZoneBottom": 1.62,
#                             "coordinates": {
#                                 "aY": 24.247427813932866,
#                                 "aZ": -36.741352973031596,
#                                 "pfxX": 9.382649921888058,
#                                 "pfxZ": -2.9651187474865264,
#                                 "pX": 0.6328815392226924,
#                                 "pZ": 1.7555639311979436,
#                                 "vX0": 1.0519440743172797,
#                                 "vY0": -123.26862595650499,
#                                 "vZ0": -1.8235200450544795,
#                                 "x": 92.88,
#                                 "y": 191.38,
#                                 "x0": -1.018411909856012,
#                                 "y0": 50.003210424217265,
#                                 "z0": 5.603645294138333,
#                                 "aX": 14.454430049089622
#                             },
#                             "breaks": {
#                                 "breakAngle": 21.6,
#                                 "breakLength": 10.8,
#                                 "breakY": 24.0,
#                                 "breakVertical": -43.7,
#                                 "breakVerticalInduced": -5.5,
#                                 "breakHorizontal": -17.3,
#                                 "spinRate": 2711,
#                                 "spinDirection": 43
#                             },
#                             "zone": 9,
#                             "typeConfidence": 0.91,
#                             "plateTime": 0.4441526328164249,
#                             "extension": 6.237608544474657
#                         },
#                         "hitData": {
#                             "launchSpeed": 85.5,
#                             "launchAngle": 32.0,
#                             "totalDistance": 298.0,
#                             "trajectory": "fly_ball",
#                             "hardness": "medium",
#                             "location": "9",
#                             "coordinates": {
#                                 "coordX": 188.23,
#                                 "coordY": 96.73
#                             }
#                         },
#                         "index": 4,
#                         "playId": "3d2af348-939d-4961-8203-a9fc1ead1fed",
#                         "pitchNumber": 2,
#                         "startTime": "2023-08-26T00:11:47.605Z",
#                         "endTime": "2023-08-26T00:11:55.544Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     }
#                 ],
#                 "playEndTime": "2023-08-26T00:11:55.544Z",
#                 "atBatIndex": 0
#             },
#             {
#                 "result": {
#                     "type": "atBat",
#                     "event": "Double",
#                     "eventType": "double",
#                     "description": "Corey Seager doubles (34) on a line drive to left fielder Matt Wallner.",
#                     "rbi": 0,
#                     "awayScore": 0,
#                     "homeScore": 0,
#                     "isOut": false
#                 },
#                 "about": {
#                     "atBatIndex": 1,
#                     "halfInning": "top",
#                     "isTopInning": true,
#                     "inning": 1,
#                     "startTime": "2023-08-26T00:12:07.114Z",
#                     "endTime": "2023-08-26T00:12:46.907Z",
#                     "isComplete": true,
#                     "isScoringPlay": false,
#                     "hasReview": false,
#                     "hasOut": false,
#                     "captivatingIndex": 34
#                 },
#                 "count": {
#                     "balls": 0,
#                     "strikes": 1,
#                     "outs": 1
#                 },
#                 "matchup": {
#                     "batter": {
#                         "id": 608369,
#                         "fullName": "Corey Seager",
#                         "link": "/api/v1/people/608369"
#                     },
#                     "batSide": {
#                         "code": "L",
#                         "description": "Left"
#                     },
#                     "pitcher": {
#                         "id": 543243,
#                         "fullName": "Sonny Gray",
#                         "link": "/api/v1/people/543243"
#                     },
#                     "pitchHand": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "postOnSecond": {
#                         "id": 608369,
#                         "fullName": "Corey Seager",
#                         "link": "/api/v1/people/608369"
#                     },
#                     "batterHotColdZones": [],
#                     "pitcherHotColdZones": [],
#                     "splits": {
#                         "batter": "vs_RHP",
#                         "pitcher": "vs_LHB",
#                         "menOnBase": "RISP"
#                     }
#                 },
#                 "pitchIndex": [
#                     0,
#                     1
#                 ],
#                 "actionIndex": [],
#                 "runnerIndex": [
#                     0
#                 ],
#                 "runners": [
#                     {
#                         "movement": {
#                             "originBase": null,
#                             "start": null,
#                             "end": "2B",
#                             "outBase": null,
#                             "isOut": false,
#                             "outNumber": null
#                         },
#                         "details": {
#                             "event": "Double",
#                             "eventType": "double",
#                             "movementReason": null,
#                             "runner": {
#                                 "id": 608369,
#                                 "fullName": "Corey Seager",
#                                 "link": "/api/v1/people/608369"
#                             },
#                             "responsiblePitcher": null,
#                             "isScoringEvent": false,
#                             "rbi": false,
#                             "earned": false,
#                             "teamUnearned": false,
#                             "playIndex": 1
#                         },
#                         "credits": [
#                             {
#                                 "player": {
#                                     "id": 670242,
#                                     "link": "/api/v1/people/670242"
#                                 },
#                                 "position": {
#                                     "code": "7",
#                                     "name": "Outfielder",
#                                     "type": "Outfielder",
#                                     "abbreviation": "LF"
#                                 },
#                                 "credit": "f_fielded_ball"
#                             }
#                         ]
#                     }
#                 ],
#                 "playEvents": [
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "T",
#                                 "description": "Foul Tip"
#                             },
#                             "description": "Foul Tip",
#                             "code": "T",
#                             "ballColor": "rgba(170, 21, 11, 1.0)",
#                             "trailColor": "rgba(188, 0, 33, 1.0)",
#                             "isInPlay": false,
#                             "isStrike": true,
#                             "isBall": false,
#                             "type": {
#                                 "code": "FF",
#                                 "description": "Four-Seam Fastball"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 1,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 93.5,
#                             "endSpeed": 86.7,
#                             "strikeZoneTop": 3.49,
#                             "strikeZoneBottom": 1.53,
#                             "coordinates": {
#                                 "aY": 25.92145867490395,
#                                 "aZ": -19.587183406147773,
#                                 "pfxX": -1.161868039416484,
#                                 "pfxZ": 6.587634805937654,
#                                 "pX": -0.049998002768367446,
#                                 "pZ": 3.614518663309518,
#                                 "vX0": 2.6014333774683993,
#                                 "vY0": -136.36872967631803,
#                                 "vZ0": -1.8822650381855386,
#                                 "x": 118.91,
#                                 "y": 141.19,
#                                 "x0": -0.8592332596124267,
#                                 "y0": 50.00371809876187,
#                                 "z0": 5.6447549524533045,
#                                 "aX": -2.2206049543196515
#                             },
#                             "breaks": {
#                                 "breakAngle": 4.8,
#                                 "breakLength": 4.8,
#                                 "breakY": 24.0,
#                                 "breakVertical": -19.0,
#                                 "breakVerticalInduced": 11.8,
#                                 "breakHorizontal": 1.7,
#                                 "spinRate": 2535,
#                                 "spinDirection": 199
#                             },
#                             "zone": 11,
#                             "typeConfidence": 0.91,
#                             "plateTime": 0.3994603517367201,
#                             "extension": 6.357331522327351
#                         },
#                         "index": 0,
#                         "playId": "d2f546fc-6dad-46dc-bd0b-582415e1c2c0",
#                         "pitchNumber": 1,
#                         "startTime": "2023-08-26T00:12:20.337Z",
#                         "endTime": "2023-08-26T00:12:23.628Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "D",
#                                 "description": "In play, no out"
#                             },
#                             "description": "In play, no out",
#                             "code": "D",
#                             "ballColor": "rgba(26, 86, 190, 1.0)",
#                             "trailColor": "rgba(0, 85, 254, 1.0)",
#                             "isInPlay": true,
#                             "isStrike": false,
#                             "isBall": false,
#                             "type": {
#                                 "code": "CH",
#                                 "description": "Changeup"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 0,
#                             "strikes": 1,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 89.6,
#                             "endSpeed": 83.0,
#                             "strikeZoneTop": 3.49,
#                             "strikeZoneBottom": 1.53,
#                             "coordinates": {
#                                 "aY": 24.88276509026651,
#                                 "aZ": -27.95428565006495,
#                                 "pfxX": -8.701950916456184,
#                                 "pfxZ": 2.420345175880758,
#                                 "pX": -0.5685595681839317,
#                                 "pZ": 2.627971565397715,
#                                 "vX0": 3.8487311937806403,
#                                 "vY0": -130.60688916334325,
#                                 "vZ0": -1.85089765045283,
#                                 "x": 138.67,
#                                 "y": 167.82,
#                                 "x0": -0.9223604474738083,
#                                 "y0": 50.00624195799632,
#                                 "z0": 5.427593747256583,
#                                 "aX": -15.189494033100532
#                             },
#                             "breaks": {
#                                 "breakAngle": 27.6,
#                                 "breakLength": 7.2,
#                                 "breakY": 24.0,
#                                 "breakVertical": -29.5,
#                                 "breakVerticalInduced": 4.2,
#                                 "breakHorizontal": 15.0,
#                                 "spinRate": 1645,
#                                 "spinDirection": 235
#                             },
#                             "zone": 4,
#                             "typeConfidence": 0.89,
#                             "plateTime": 0.41774937957917313,
#                             "extension": 6.167919595697684
#                         },
#                         "hitData": {
#                             "launchSpeed": 91.6,
#                             "launchAngle": 24.0,
#                             "totalDistance": 293.0,
#                             "trajectory": "line_drive",
#                             "hardness": "medium",
#                             "location": "7",
#                             "coordinates": {
#                                 "coordX": 34.94,
#                                 "coordY": 105.85
#                             }
#                         },
#                         "index": 1,
#                         "playId": "3f30cc24-5bea-4171-acf1-0f09a0761fec",
#                         "pitchNumber": 2,
#                         "startTime": "2023-08-26T00:12:34.590Z",
#                         "endTime": "2023-08-26T00:12:46.907Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     }
#                 ],
#                 "playEndTime": "2023-08-26T00:12:46.907Z",
#                 "atBatIndex": 1
#             },
#             {
#                 "result": {
#                     "type": "atBat",
#                     "event": "Flyout",
#                     "eventType": "field_out",
#                     "description": "Nathaniel Lowe flies out to left fielder Matt Wallner.",
#                     "rbi": 0,
#                     "awayScore": 0,
#                     "homeScore": 0,
#                     "isOut": true
#                 },
#                 "about": {
#                     "atBatIndex": 2,
#                     "halfInning": "top",
#                     "isTopInning": true,
#                     "inning": 1,
#                     "startTime": "2023-08-26T00:13:06.153Z",
#                     "endTime": "2023-08-26T00:14:40.153Z",
#                     "isComplete": true,
#                     "isScoringPlay": false,
#                     "hasReview": false,
#                     "hasOut": true,
#                     "captivatingIndex": 0
#                 },
#                 "count": {
#                     "balls": 2,
#                     "strikes": 1,
#                     "outs": 2
#                 },
#                 "matchup": {
#                     "batter": {
#                         "id": 663993,
#                         "fullName": "Nathaniel Lowe",
#                         "link": "/api/v1/people/663993"
#                     },
#                     "batSide": {
#                         "code": "L",
#                         "description": "Left"
#                     },
#                     "pitcher": {
#                         "id": 543243,
#                         "fullName": "Sonny Gray",
#                         "link": "/api/v1/people/543243"
#                     },
#                     "pitchHand": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "postOnSecond": {
#                         "id": 608369,
#                         "fullName": "Corey Seager",
#                         "link": "/api/v1/people/608369"
#                     },
#                     "batterHotColdZones": [],
#                     "pitcherHotColdZones": [],
#                     "splits": {
#                         "batter": "vs_RHP",
#                         "pitcher": "vs_LHB",
#                         "menOnBase": "RISP"
#                     }
#                 },
#                 "pitchIndex": [
#                     0,
#                     1,
#                     2,
#                     3
#                 ],
#                 "actionIndex": [],
#                 "runnerIndex": [
#                     0
#                 ],
#                 "runners": [
#                     {
#                         "movement": {
#                             "originBase": null,
#                             "start": null,
#                             "end": null,
#                             "outBase": "1B",
#                             "isOut": true,
#                             "outNumber": 2
#                         },
#                         "details": {
#                             "event": "Flyout",
#                             "eventType": "field_out",
#                             "movementReason": null,
#                             "runner": {
#                                 "id": 663993,
#                                 "fullName": "Nathaniel Lowe",
#                                 "link": "/api/v1/people/663993"
#                             },
#                             "responsiblePitcher": null,
#                             "isScoringEvent": false,
#                             "rbi": false,
#                             "earned": false,
#                             "teamUnearned": false,
#                             "playIndex": 3
#                         },
#                         "credits": [
#                             {
#                                 "player": {
#                                     "id": 670242,
#                                     "link": "/api/v1/people/670242"
#                                 },
#                                 "position": {
#                                     "code": "7",
#                                     "name": "Outfielder",
#                                     "type": "Outfielder",
#                                     "abbreviation": "LF"
#                                 },
#                                 "credit": "f_putout"
#                             }
#                         ]
#                     }
#                 ],
#                 "playEvents": [
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "B",
#                                 "description": "Ball"
#                             },
#                             "description": "Ball",
#                             "code": "B",
#                             "ballColor": "rgba(39, 161, 39, 1.0)",
#                             "trailColor": "rgba(188, 0, 33, 1.0)",
#                             "isInPlay": false,
#                             "isStrike": false,
#                             "isBall": true,
#                             "type": {
#                                 "code": "FF",
#                                 "description": "Four-Seam Fastball"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 1,
#                             "strikes": 0,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 93.2,
#                             "endSpeed": 86.3,
#                             "strikeZoneTop": 3.68550858627162,
#                             "strikeZoneBottom": 1.60913108464335,
#                             "coordinates": {
#                                 "aY": 26.1413049764354,
#                                 "aZ": -16.686423114196806,
#                                 "pfxX": -2.403636582485275,
#                                 "pfxZ": 8.22179291187668,
#                                 "pX": 1.2701619113829608,
#                                 "pZ": 1.6542793783645238,
#                                 "vX0": 6.226636086179383,
#                                 "vY0": -135.55651603937372,
#                                 "vZ0": -6.906763698101408,
#                                 "x": 68.58,
#                                 "y": 194.11,
#                                 "x0": -0.7317144206653607,
#                                 "y0": 50.00641871858032,
#                                 "z0": 5.374838808333959,
#                                 "aX": -4.530328965636836
#                             },
#                             "breaks": {
#                                 "breakAngle": 10.8,
#                                 "breakLength": 3.6,
#                                 "breakY": 24.0,
#                                 "breakVertical": -17.4,
#                                 "breakVerticalInduced": 13.8,
#                                 "breakHorizontal": 3.2,
#                                 "spinRate": 2508,
#                                 "spinDirection": 203
#                             },
#                             "zone": 14,
#                             "typeConfidence": 0.87,
#                             "plateTime": 0.4021189237650211,
#                             "extension": 6.4570835891153555
#                         },
#                         "index": 0,
#                         "playId": "dd33774d-d7e9-469e-8a88-4e0c37c32751",
#                         "pitchNumber": 1,
#                         "startTime": "2023-08-26T00:13:23.314Z",
#                         "endTime": "2023-08-26T00:13:27.650Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "B",
#                                 "description": "Ball"
#                             },
#                             "description": "Ball",
#                             "code": "B",
#                             "ballColor": "rgba(39, 161, 39, 1.0)",
#                             "trailColor": "rgba(188, 0, 33, 1.0)",
#                             "isInPlay": false,
#                             "isStrike": false,
#                             "isBall": true,
#                             "type": {
#                                 "code": "FF",
#                                 "description": "Four-Seam Fastball"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 2,
#                             "strikes": 0,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 93.9,
#                             "endSpeed": 86.5,
#                             "strikeZoneTop": 3.59808406233882,
#                             "strikeZoneBottom": 1.62320230310858,
#                             "coordinates": {
#                                 "aY": 27.706505793516133,
#                                 "aZ": -16.91496515881435,
#                                 "pfxX": -2.1749376477355593,
#                                 "pfxZ": 7.990978838540384,
#                                 "pX": 1.3574857040852435,
#                                 "pZ": 3.4644049712178995,
#                                 "vX0": 6.445599204179556,
#                                 "vY0": -136.74343633060755,
#                                 "vZ0": -2.653158284696984,
#                                 "x": 65.26,
#                                 "y": 145.24,
#                                 "x0": -0.7387753273133557,
#                                 "y0": 50.00623336301042,
#                                 "z0": 5.595923144019921,
#                                 "aX": -4.1554051912609005
#                             },
#                             "breaks": {
#                                 "breakAngle": 9.6,
#                                 "breakLength": 3.6,
#                                 "breakY": 24.0,
#                                 "breakVertical": -16.6,
#                                 "breakVerticalInduced": 14.2,
#                                 "breakHorizontal": 2.8,
#                                 "spinRate": 2530,
#                                 "spinDirection": 206
#                             },
#                             "zone": 12,
#                             "typeConfidence": 0.91,
#                             "plateTime": 0.3992358041470001,
#                             "extension": 6.197130030307117
#                         },
#                         "index": 1,
#                         "playId": "74726760-955a-478d-8015-91d16f5f06e9",
#                         "pitchNumber": 2,
#                         "startTime": "2023-08-26T00:13:41.578Z",
#                         "endTime": "2023-08-26T00:13:45.779Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "F",
#                                 "description": "Foul"
#                             },
#                             "description": "Foul",
#                             "code": "F",
#                             "ballColor": "rgba(170, 21, 11, 1.0)",
#                             "trailColor": "rgba(152, 0, 101, 1.0)",
#                             "isInPlay": false,
#                             "isStrike": true,
#                             "isBall": false,
#                             "type": {
#                                 "code": "FC",
#                                 "description": "Cutter"
#                             },
#                             "isOut": false,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 2,
#                             "strikes": 1,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 87.3,
#                             "endSpeed": 79.7,
#                             "strikeZoneTop": 3.48,
#                             "strikeZoneBottom": 1.61,
#                             "coordinates": {
#                                 "aY": 28.000606297962996,
#                                 "aZ": -35.754609717794736,
#                                 "pfxX": 2.3751482611267365,
#                                 "pfxZ": -2.20854047579717,
#                                 "pX": 0.0045422939449916225,
#                                 "pZ": 2.3409181789847966,
#                                 "vX0": 1.2925438858636986,
#                                 "vY0": -127.06224770807997,
#                                 "vZ0": -1.1301892571416257,
#                                 "x": 116.83,
#                                 "y": 175.58,
#                                 "x0": -0.8206391532806342,
#                                 "y0": 50.003319194257614,
#                                 "z0": 5.653393977683593,
#                                 "aX": 3.85162247388834
#                             },
#                             "breaks": {
#                                 "breakAngle": 6.0,
#                                 "breakLength": 9.6,
#                                 "breakY": 24.0,
#                                 "breakVertical": -40.1,
#                                 "breakVerticalInduced": -4.0,
#                                 "breakHorizontal": -4.6,
#                                 "spinRate": 2641,
#                                 "spinDirection": 96
#                             },
#                             "zone": 5,
#                             "typeConfidence": 0.91,
#                             "plateTime": 0.43242623961851523,
#                             "extension": 6.2364125429076696
#                         },
#                         "index": 2,
#                         "playId": "a1c56347-d048-4c2b-bbbc-9098dce05144",
#                         "pitchNumber": 3,
#                         "startTime": "2023-08-26T00:14:02.426Z",
#                         "endTime": "2023-08-26T00:14:07.203Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     },
#                     {
#                         "details": {
#                             "call": {
#                                 "code": "X",
#                                 "description": "In play, out(s)"
#                             },
#                             "description": "In play, out(s)",
#                             "code": "X",
#                             "ballColor": "rgba(26, 86, 190, 1.0)",
#                             "trailColor": "rgba(188, 0, 33, 1.0)",
#                             "isInPlay": true,
#                             "isStrike": false,
#                             "isBall": false,
#                             "type": {
#                                 "code": "FF",
#                                 "description": "Four-Seam Fastball"
#                             },
#                             "isOut": true,
#                             "hasReview": false
#                         },
#                         "count": {
#                             "balls": 2,
#                             "strikes": 1,
#                             "outs": 1
#                         },
#                         "pitchData": {
#                             "startSpeed": 94.0,
#                             "endSpeed": 85.9,
#                             "strikeZoneTop": 3.48,
#                             "strikeZoneBottom": 1.61,
#                             "coordinates": {
#                                 "aY": 30.402173221402162,
#                                 "aZ": -13.38413199574628,
#                                 "pfxX": -2.467397066143649,
#                                 "pfxZ": 9.937826307659464,
#                                 "pX": 0.5533255911797309,
#                                 "pZ": 2.1665761530013867,
#                                 "vX0": 4.296490655189597,
#                                 "vY0": -136.70296231200294,
#                                 "vZ0": -6.265103854128624,
#                                 "x": 95.91,
#                                 "y": 180.28,
#                                 "x0": -0.718853117263305,
#                                 "y0": 50.005148479117246,
#                                 "z0": 5.408695899920592,
#                                 "aX": -4.666702434189045
#                             },
#                             "breaks": {
#                                 "breakAngle": 14.4,
#                                 "breakLength": 3.6,
#                                 "breakY": 24.0,
#                                 "breakVertical": -14.2,
#                                 "breakVerticalInduced": 16.8,
#                                 "breakHorizontal": 3.6,
#                                 "spinRate": 2473,
#                                 "spinDirection": 203
#                             },
#                             "zone": 9,
#                             "typeConfidence": 0.9,
#                             "plateTime": 0.40081950805903865,
#                             "extension": 6.392788337077877
#                         },
#                         "hitData": {
#                             "launchSpeed": 89.0,
#                             "launchAngle": 52.0,
#                             "totalDistance": 267.0,
#                             "trajectory": "fly_ball",
#                             "hardness": "medium",
#                             "location": "7",
#                             "coordinates": {
#                                 "coordX": 48.21,
#                                 "coordY": 124.71
#                             }
#                         },
#                         "index": 3,
#                         "playId": "9242f22e-bd78-477d-a903-7bd81b6bebd7",
#                         "pitchNumber": 4,
#                         "startTime": "2023-08-26T00:14:26.714Z",
#                         "endTime": "2023-08-26T00:14:40.153Z",
#                         "isPitch": true,
#                         "type": "pitch"
#                     }
#                 ],
#                 "playEndTime": "2023-08-26T00:14:40.153Z",
#                 "atBatIndex": 2
#             },
#             {
#                 "result": {
#                     "type": "atBat",
#                     "event": "Strikeout",
#                     "eventType": "strikeout",
#                     "description": "Adolis Garcia strikes out swinging.",
#                     "rbi": 0,
#                     "awayScore": 0,
#                     "homeScore": 0,
#                     "isOut": true
#                 },
#                 "about": {
#                     "atBatIndex": 3,
#                     "halfInning": "top",
#                     "isTopInning": true,
#                     "inning": 1,
#                     "startTime": "2023-08-26T00:14:51.778Z",
#                     "endTime": "2023-08-26T00:16:13.598Z",
#                     "isComplete": true,
#                     "isScoringPlay": false,
#                     "hasReview": false,
#                     "hasOut": true,
#                     "captivatingIndex": 14
#                 },
#                 "count": {
#                     "balls": 1,
#                     "strikes": 3,
#                     "outs": 3
#                 },
#                 "matchup": {
#                     "batter": {
#                         "id": 666969,
#                         "fullName": "Adolis Garcia",
#                         "link": "/api/v1/people/666969"
#                     },
#                     "batSide": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "pitcher": {
#                         "id": 543243,
#                         "fullName": "Sonny Gray",
#                         "link": "/api/v1/people/543243"
#                     },
#                     "pitchHand": {
#                         "code": "R",
#                         "description": "Right"
#                     },
#                     "batterHotColdZones": [],
#                     "pitcherHotColdZones": [],
#                     "splits": {
#                         "batter": "vs_RHP",
#                         "pitcher": "vs_RHB",
#                         "menOnBase": "Empty"
#                     }
#                 },
#                 "pitchIndex": [
#                     0,
#                     1,
#                     2,
#                     3
#                 ],
#                 "actionIndex": [],
#                 "runnerIndex": [
#                     0
#                 ],
#                 "runners": [
#                     {
#                         "movement": {
#                             "originBase": null,
#                             "start": null,
#                             "end": null,
# ...
#                         "parentTeamId": 142,
#                         "battingOrder": "600",
#                         "stats": {
#                             "batting": {
#                                 "summary": "2-4 | 3B, 2B, HBP",
#                                 "gamesPlayed": 1,
#                                 "flyOuts": 0,
#                                 "groundOuts": 1,
#                                 "runs": 3,
#                                 "doubles": 1,
#                                 "triples": 1,
#                                 "homeRuns": 0,
#                                 "strikeOuts": 1,
#                                 "baseOnBalls": 0,
#                                 "intentionalWalks": 0,
#                                 "hits": 2,
#                                 "hitByPitch": 1,
#                                 "atBats": 4,
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "groundIntoDoublePlay": 0,
#                                 "groundIntoTriplePlay": 0,
#                                 "plateAppearances": 5,
#                                 "totalBases": 5,
#                                 "rbi": 3,
#                                 "leftOnBase": 2,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "catchersInterference": 0,
#                                 "pickoffs": 0,
#                                 "atBatsPerHomeRun": "-.--"
#                             },
#                             "pitching": {},
#                             "fielding": {
#                                 "gamesStarted": 1,
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "assists": 0,
#                                 "putOuts": 4,
#                                 "errors": 0,
#                                 "chances": 4,
#                                 "fielding": ".000",
#                                 "passedBall": 0,
#                                 "pickoffs": 0
#                             }
#                         },
#                         "seasonStats": {
#                             "batting": {
#                                 "gamesPlayed": 45,
#                                 "flyOuts": 0,
#                                 "groundOuts": 18,
#                                 "runs": 25,
#                                 "doubles": 6,
#                                 "triples": 1,
#                                 "homeRuns": 9,
#                                 "strikeOuts": 45,
#                                 "baseOnBalls": 10,
#                                 "intentionalWalks": 0,
#                                 "hits": 30,
#                                 "hitByPitch": 10,
#                                 "avg": ".244",
#                                 "atBats": 123,
#                                 "obp": ".350",
#                                 "slg": ".528",
#                                 "ops": ".878",
#                                 "caughtStealing": 1,
#                                 "stolenBases": 2,
#                                 "stolenBasePercentage": ".667",
#                                 "groundIntoDoublePlay": 0,
#                                 "groundIntoTriplePlay": 0,
#                                 "plateAppearances": 143,
#                                 "totalBases": 65,
#                                 "rbi": 25,
#                                 "leftOnBase": 56,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "babip": ".304",
#                                 "catchersInterference": 0,
#                                 "pickoffs": 0,
#                                 "atBatsPerHomeRun": "13.67"
#                             },
#                             "pitching": {
#                                 "gamesPlayed": 0,
#                                 "gamesStarted": 0,
#                                 "groundOuts": 0,
#                                 "airOuts": 0,
#                                 "runs": 0,
#                                 "doubles": 0,
#                                 "triples": 0,
#                                 "homeRuns": 0,
#                                 "strikeOuts": 0,
#                                 "baseOnBalls": 0,
#                                 "intentionalWalks": 0,
#                                 "hits": 0,
#                                 "hitByPitch": 0,
#                                 "atBats": 0,
#                                 "obp": ".000",
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "numberOfPitches": 0,
#                                 "era": "-.--",
#                                 "inningsPitched": "0.0",
#                                 "wins": 0,
#                                 "losses": 0,
#                                 "saves": 0,
#                                 "saveOpportunities": 0,
#                                 "holds": 0,
#                                 "blownSaves": 0,
#                                 "earnedRuns": 0,
#                                 "whip": "-",
#                                 "battersFaced": 0,
#                                 "outs": 0,
#                                 "gamesPitched": 0,
#                                 "completeGames": 0,
#                                 "shutouts": 0,
#                                 "balls": 0,
#                                 "strikes": 0,
#                                 "strikePercentage": "-.--",
#                                 "hitBatsmen": 0,
#                                 "balks": 0,
#                                 "wildPitches": 0,
#                                 "pickoffs": 0,
#                                 "groundOutsToAirouts": "-.--",
#                                 "rbi": 0,
#                                 "winPercentage": ".---",
#                                 "pitchesPerInning": "-.--",
#                                 "gamesFinished": 0,
#                                 "strikeoutWalkRatio": "-.--",
#                                 "strikeoutsPer9Inn": "-.--",
#                                 "walksPer9Inn": "-.--",
#                                 "hitsPer9Inn": "-.--",
#                                 "runsScoredPer9": "-.--",
#                                 "homeRunsPer9": "-.--",
#                                 "inheritedRunners": 0,
#                                 "inheritedRunnersScored": 0,
#                                 "catchersInterference": 0,
#                                 "sacBunts": 0,
#                                 "sacFlies": 0,
#                                 "passedBall": 0
#                             },
#                             "fielding": {
#                                 "gamesStarted": 1,
#                                 "caughtStealing": 0,
#                                 "stolenBases": 0,
#                                 "stolenBasePercentage": ".---",
#                                 "assists": 2,
#                                 "putOuts": 57,
#                                 "errors": 1,
#                                 "chances": 60,
#                                 "fielding": ".983",
#                                 "passedBall": 0,
#                                 "pickoffs": 0
#                             }
#                         },
#                         "gameStatus": {
#                             "isCurrentBatter": false,
#                             "isCurrentPitcher": false,
#                             "isOnBench": false,
#                             "isSubstitute": false
#                         },
#                         "allPositions": [
#                             {
#                                 "code": "7",
#                                 "name": "Outfielder",
#                                 "type": "Outfielder",
#                                 "abbreviation": "LF"
#                             }
#                         ]
#                     }
#                 },
#                 "batters": [
#                     666397,
#                     593871,
#                     621043,
#                     596146,
#                     668904,
#                     670242,
#                     680777,
#                     608336,
#                     656669,
#                     456781,
#                     543243,
#                     663485
#                 ],
#                 "pitchers": [
#                     543243,
#                     663485
#                 ],
#                 "bench": [
#                     571657,
#                     572191,
#                     543877
#                 ],
#                 "bullpen": [
#                     666364,
#                     661395,
#                     571670,
#                     643377,
#                     572971,
#                     641154,
#                     628317,
#                     641927,
#                     641941,
#                     573204,
#                     680739
#                 ],
#                 "battingOrder": [
#                     666397,
#                     593871,
#                     621043,
#                     596146,
#                     668904,
#                     670242,
#                     680777,
#                     656669,
#                     456781
#                 ],
#                 "info": [
#                     {
#                         "title": "BATTING",
#                         "fieldList": [
#                             {
#                                 "label": "2B",
#                                 "value": "Kepler (16, Dunning); Wallner (6, Hedges)."
#                             },
#                             {
#                                 "label": "3B",
#                                 "value": "Wallner (1, Dunning)."
#                             },
#                             {
#                                 "label": "HR",
#                                 "value": "Correa (16, 7th inning off P\u00e9rez, M, 0 on, 0 out); Julien (11, 7th inning off Anderson, G, 2 on, 2 out); Kepler (21, 8th inning off Hedges, 0 on, 0 out)."
#                             },
#                             {
#                                 "label": "TB",
#                                 "value": "Correa 4; Jeffers 2; Julien 4; Kepler 6; Lewis; Polanco; Solano 2; Wallner 5."
#                             },
#                             {
#                                 "label": "RBI",
#                                 "value": "Correa (57); Jeffers 2 (30); Julien 3 (25); Kepler (49); Solano 2 (28); Wallner 3 (25)."
#                             },
#                             {
#                                 "label": "2-out RBI",
#                                 "value": "Jeffers; Julien 3; Wallner 3; Solano 2."
#                             },
#                             {
#                                 "label": "Runners left in scoring position, 2 out",
#                                 "value": "Lewis 2; Julien; Gallo 2."
#                             },
#                             {
#                                 "label": "GIDP",
#                                 "value": "Correa."
#                             },
#                             {
#                                 "label": "Team RISP",
#                                 "value": "7-for-15."
#                             },
#                             {
#                                 "label": "Team LOB",
#                                 "value": "10."
#                             }
#                         ]
#                     },
#                     {
#                         "title": "FIELDING",
#                         "fieldList": [
#                             {
#                                 "label": "PB",
#                                 "value": "Jeffers (4)."
#                             },
#                             {
#                                 "label": "DP",
#                                 "value": "(Polanco-Correa-Solano)."
#                             }
#                         ]
#                     }
#                 ],
#                 "note": []
#             }
#         },
#         "officials": [
#             {
#                 "official": {
#                     "id": 547380,
#                     "fullName": "Carlos Torres",
#                     "link": "/api/v1/people/547380"
#                 },
#                 "officialType": "Home Plate"
#             },
#             {
#                 "official": {
#                     "id": 596740,
#                     "fullName": "Jansen Visconti",
#                     "link": "/api/v1/people/596740"
#                 },
#                 "officialType": "First Base"
#             },
#             {
#                 "official": {
#                     "id": 545402,
#                     "fullName": "John Bacon",
#                     "link": "/api/v1/people/545402"
#                 },
#                 "officialType": "Second Base"
#             },
#             {
#                 "official": {
#                     "id": 484183,
#                     "fullName": "Cory Blaser",
#                     "link": "/api/v1/people/484183"
#                 },
#                 "officialType": "Third Base"
#             }
#         ],
#         "info": [
#             {
#                 "label": "WP",
#                 "value": "Gray, So."
#             },
#             {
#                 "label": "HBP",
#                 "value": "Garver (by Gray, So); Jeffers 2 (by Dunning, by Hedges); Wallner (by P\u00e9rez, M)."
#             },
#             {
#                 "label": "Pitches-strikes",
#                 "value": "Dunning 82-44; P\u00e9rez, M 23-16; Anderson, G 22-14; Hedges 26-16; Gray, So 81-53; Sands 32-20."
#             },
#             {
#                 "label": "Groundouts-flyouts",
#                 "value": "Dunning 3-2; P\u00e9rez, M 6-0; Anderson, G 1-0; Hedges 0-2; Gray, So 7-7; Sands 3-1."
#             },
#             {
#                 "label": "Batters faced",
#                 "value": "Dunning 23; P\u00e9rez, M 10; Anderson, G 6; Hedges 7; Gray, So 27; Sands 8."
#             },
#             {
#                 "label": "Inherited runners-scored",
#                 "value": "Anderson, G 2-2."
#             },
#             {
#                 "label": "Ejections",
#                 "value": "Twins center fielder Joey Gallo ejected by HP umpire Carlos Torres (4th); Twins manager Rocco Baldelli ejected by HP umpire Carlos Torres (4th)."
#             },
#             {
#                 "label": "Umpires",
#                 "value": "HP: Carlos Torres. 1B: Jansen Visconti. 2B: John Bacon. 3B: Cory Blaser. "
#             },
#             {
#                 "label": "Weather",
#                 "value": "84 degrees, Partly Cloudy."
#             },
#             {
#                 "label": "Wind",
#                 "value": "11 mph, Out To RF."
#             },
#             {
#                 "label": "First pitch",
#                 "value": "7:11 PM."
#             },
#             {
#                 "label": "T",
#                 "value": "2:25."
#             },
#             {
#                 "label": "Att",
#                 "value": "25,144."
#             },
#             {
#                 "label": "Venue",
#                 "value": "Target Field."
#             },
#             {
#                 "label": "August 25, 2023"
#             }
#         ],
#         "pitchingNotes": []
#     },
#     "decisions": {
#         "winner": {
#             "id": 543243,
#             "fullName": "Sonny Gray",
#             "link": "/api/v1/people/543243"
#         },
#         "loser": {
#             "id": 641540,
#             "fullName": "Dane Dunning",
#             "link": "/api/v1/people/641540"
#         }
#     },
#     "leaders": {
#         "hitDistance": {},
#         "hitSpeed": {},
#         "pitchSpeed": {}
#     }
# }
