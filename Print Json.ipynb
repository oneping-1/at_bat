# %%
import json
from get.statsapi_plus import get_game_dict

data = get_game_dict(717402, 43)

with open('json.txt', 'w') as file:
    file.write(json.dumps(data, indent=4))

# %%
from get.statsapi_plus import get_game_dict

get_game_dict(gamePk=717404, delay_seconds=int(1))
# Out:
# {'copyright': 'Copyright 2023 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'gamePk': 717404,
#  'link': '/api/v1.1/game/717404/feed/live',
#  'metaData': {'wait': 10,
#   'timeStamp': '20230715_214500',
#   'gameEvents': ['field_out', 'game_finished'],
#   'logicalEvents': ['midInning',
#    'countChange',
#    'count11',
#    'newLeftHandedHit',
#    'basesEmpty',
#    'gameStateChangeToGameOver']},
#  'gameData': {'game': {'pk': 717404,
#    'type': 'R',
#    'doubleHeader': 'N',
#    'id': '2023/07/15/arimlb-tormlb-1',
#    'gamedayType': 'P',
#    'tiebreaker': 'N',
#    'gameNumber': 1,
#    'calendarEventID': '14-717404-2023-07-15',
#    'season': '2023',
#    'seasonDisplay': '2023'},
#   'datetime': {'dateTime': '2023-07-15T19:07:00Z',
#    'originalDate': '2023-07-15',
#    'officialDate': '2023-07-15',
#    'dayNight': 'day',
#    'time': '3:07',
# ...

# %%
print(isinstance(1, float))
# Out:
# False
